# %%
import os
import scanpy as sc
import scvi
import json
from sklearn.model_selection import train_test_split
import numpy as np
import json
import anndata

# %% [markdown]
# ## Read data

# %%
DATA_DIR = "../data_centralized"
TRAIN_PATH  = os.path.join(DATA_DIR, "pancreas_train.h5ad")

pancreas_train = anndata.read_h5ad(TRAIN_PATH)

# Utility to load HVG list
def load_hvg_list(hvg_list_path):
    with open(hvg_list_path) as f:
        return json.load(f)

hvg_list = load_hvg_list(os.path.join(DATA_DIR, "top2k_genes.json"))

# Restrict to HVG genes
pancreas_train = pancreas_train[:, hvg_list].copy()

# %% [markdown]
# ## Train of scVI model

# %%
scvi.model.SCVI.setup_anndata(pancreas_train, batch_key="tech", layer="counts")

scvi_ref = scvi.model.SCVI(
    pancreas_train,
    use_layer_norm="both",
    use_batch_norm="none",
    encode_covariates=True,
    dropout_rate=0.2,
    n_layers=2,
)
scvi_ref.train(max_epochs=50)
# Out:
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/data/fields/_base_field.py:63: UserWarning: adata.layers[counts] does not contain unnormalized count data. Are you sure this is what you want?
#   self.validate_field(adata)
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/train/_trainrunner.py:69: UserWarning: `accelerator` has been automatically set to `cpu` although 'mps' exists. If you wish to run on mps backend, use explicitly accelerator='mps' in train function.In future releases it will become default for mps supported machines.
#   accelerator, lightning_devices, device = parse_device_args(
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/lightning/pytorch/trainer/setup.py:175: GPU available but not used. You can set it by doing `Trainer(accelerator='gpu')`.
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:434: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=7` in the `DataLoader` to improve performance.
# Epoch 1/50:   0%|          | 0/50 [00:00<?, ?it/s]
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# Epoch 2/50:   2%|▏         | 1/50 [00:01<01:08,  1.40s/it, v_num=1, train_loss_step=1.54e+3, train_loss_epoch=1.45e+3]
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# Epoch 3/50:   4%|▍         | 2/50 [00:02<01:06,  1.39s/it, v_num=1, train_loss_step=1.01e+3, train_loss_epoch=1.25e+3]
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# Epoch 4/50:   6%|▌         | 3/50 [00:04<01:04,  1.37s/it, v_num=1, train_loss_step=1.12e+3, train_loss_epoch=1.16e+3]
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# Epoch 5/50:   8%|▊         | 4/50 [00:05<01:02,  1.35s/it, v_num=1, train_loss_step=1.43e+3, train_loss_epoch=1.1e+3]
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# Epoch 6/50:  10%|█         | 5/50 [00:06<00:59,  1.33s/it, v_num=1, train_loss_step=1.28e+3, train_loss_epoch=1.07e+3]
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# Epoch 7/50:  12%|█▏        | 6/50 [00:08<00:58,  1.33s/it, v_num=1, train_loss_step=1.15e+3, train_loss_epoch=1.05e+3]
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# Epoch 8/50:  14%|█▍        | 7/50 [00:09<00:57,  1.33s/it, v_num=1, train_loss_step=977, train_loss_epoch=1.04e+3]
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# Epoch 9/50:  16%|█▌        | 8/50 [00:10<00:55,  1.32s/it, v_num=1, train_loss_step=1.05e+3, train_loss_epoch=1.03e+3]
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# Epoch 10/50:  18%|█▊        | 9/50 [00:12<00:54,  1.32s/it, v_num=1, train_loss_step=916, train_loss_epoch=1.02e+3]
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# Epoch 11/50:  20%|██        | 10/50 [00:13<00:53,  1.33s/it, v_num=1, train_loss_step=956, train_loss_epoch=1.01e+3]
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# Epoch 12/50:  22%|██▏       | 11/50 [00:14<00:52,  1.34s/it, v_num=1, train_loss_step=1.02e+3, train_loss_epoch=1.01e+3]
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# Epoch 13/50:  24%|██▍       | 12/50 [00:16<00:50,  1.34s/it, v_num=1, train_loss_step=1.24e+3, train_loss_epoch=1e+3]
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# Epoch 14/50:  26%|██▌       | 13/50 [00:17<00:49,  1.33s/it, v_num=1, train_loss_step=1.09e+3, train_loss_epoch=998]
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# Epoch 15/50:  28%|██▊       | 14/50 [00:18<00:48,  1.34s/it, v_num=1, train_loss_step=1.02e+3, train_loss_epoch=993]
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# Epoch 16/50:  30%|███       | 15/50 [00:20<00:46,  1.34s/it, v_num=1, train_loss_step=1.2e+3, train_loss_epoch=989]
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# Epoch 17/50:  32%|███▏      | 16/50 [00:21<00:45,  1.34s/it, v_num=1, train_loss_step=965, train_loss_epoch=986]
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# Epoch 18/50:  34%|███▍      | 17/50 [00:22<00:44,  1.34s/it, v_num=1, train_loss_step=1.11e+3, train_loss_epoch=983]
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# Epoch 19/50:  36%|███▌      | 18/50 [00:24<00:43,  1.34s/it, v_num=1, train_loss_step=786, train_loss_epoch=980]
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# Epoch 20/50:  38%|███▊      | 19/50 [00:25<00:42,  1.38s/it, v_num=1, train_loss_step=931, train_loss_epoch=977]
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# Epoch 21/50:  40%|████      | 20/50 [00:27<00:42,  1.43s/it, v_num=1, train_loss_step=863, train_loss_epoch=975]
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# Epoch 22/50:  42%|████▏     | 21/50 [00:28<00:41,  1.45s/it, v_num=1, train_loss_step=1.01e+3, train_loss_epoch=973]
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# Epoch 23/50:  44%|████▍     | 22/50 [00:29<00:39,  1.42s/it, v_num=1, train_loss_step=925, train_loss_epoch=970]
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# Epoch 24/50:  46%|████▌     | 23/50 [00:31<00:38,  1.41s/it, v_num=1, train_loss_step=1.08e+3, train_loss_epoch=968]
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# Epoch 25/50:  48%|████▊     | 24/50 [00:32<00:36,  1.41s/it, v_num=1, train_loss_step=1.03e+3, train_loss_epoch=966]
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# Epoch 26/50:  50%|█████     | 25/50 [00:34<00:35,  1.42s/it, v_num=1, train_loss_step=1.12e+3, train_loss_epoch=964]
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# Epoch 27/50:  52%|█████▏    | 26/50 [00:35<00:34,  1.45s/it, v_num=1, train_loss_step=1.06e+3, train_loss_epoch=963]
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# Epoch 28/50:  54%|█████▍    | 27/50 [00:37<00:33,  1.45s/it, v_num=1, train_loss_step=919, train_loss_epoch=961]
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# Epoch 29/50:  56%|█████▌    | 28/50 [00:38<00:31,  1.43s/it, v_num=1, train_loss_step=988, train_loss_epoch=960]
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# Epoch 30/50:  58%|█████▊    | 29/50 [00:39<00:29,  1.41s/it, v_num=1, train_loss_step=904, train_loss_epoch=958]
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# Epoch 31/50:  60%|██████    | 30/50 [00:41<00:27,  1.40s/it, v_num=1, train_loss_step=1e+3, train_loss_epoch=957]
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# Epoch 32/50:  62%|██████▏   | 31/50 [00:42<00:26,  1.41s/it, v_num=1, train_loss_step=902, train_loss_epoch=956]
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# Epoch 33/50:  64%|██████▍   | 32/50 [00:44<00:25,  1.40s/it, v_num=1, train_loss_step=1.01e+3, train_loss_epoch=954]
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# Epoch 34/50:  66%|██████▌   | 33/50 [00:45<00:23,  1.40s/it, v_num=1, train_loss_step=853, train_loss_epoch=953]
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# Epoch 35/50:  68%|██████▊   | 34/50 [00:46<00:22,  1.39s/it, v_num=1, train_loss_step=925, train_loss_epoch=952]
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# Epoch 36/50:  70%|███████   | 35/50 [00:48<00:20,  1.39s/it, v_num=1, train_loss_step=1.14e+3, train_loss_epoch=951]
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# Epoch 37/50:  72%|███████▏  | 36/50 [00:49<00:19,  1.39s/it, v_num=1, train_loss_step=967, train_loss_epoch=950]
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# Epoch 38/50:  74%|███████▍  | 37/50 [00:51<00:17,  1.38s/it, v_num=1, train_loss_step=1.02e+3, train_loss_epoch=949]
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# Epoch 39/50:  76%|███████▌  | 38/50 [00:52<00:16,  1.39s/it, v_num=1, train_loss_step=942, train_loss_epoch=948]
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# Epoch 40/50:  78%|███████▊  | 39/50 [00:53<00:15,  1.39s/it, v_num=1, train_loss_step=881, train_loss_epoch=947]
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# Epoch 41/50:  80%|████████  | 40/50 [00:55<00:13,  1.38s/it, v_num=1, train_loss_step=982, train_loss_epoch=947]
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# Epoch 42/50:  82%|████████▏ | 41/50 [00:56<00:12,  1.38s/it, v_num=1, train_loss_step=963, train_loss_epoch=946]
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# Epoch 43/50:  84%|████████▍ | 42/50 [00:57<00:11,  1.39s/it, v_num=1, train_loss_step=1.05e+3, train_loss_epoch=945]
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# Epoch 44/50:  86%|████████▌ | 43/50 [00:59<00:09,  1.38s/it, v_num=1, train_loss_step=972, train_loss_epoch=944]
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# Epoch 45/50:  88%|████████▊ | 44/50 [01:00<00:08,  1.39s/it, v_num=1, train_loss_step=976, train_loss_epoch=944]
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# Epoch 46/50:  90%|█████████ | 45/50 [01:02<00:06,  1.40s/it, v_num=1, train_loss_step=820, train_loss_epoch=943]
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# Epoch 47/50:  92%|█████████▏| 46/50 [01:03<00:05,  1.39s/it, v_num=1, train_loss_step=824, train_loss_epoch=942]
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# Epoch 48/50:  94%|█████████▍| 47/50 [01:04<00:04,  1.40s/it, v_num=1, train_loss_step=966, train_loss_epoch=942]
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# Epoch 49/50:  96%|█████████▌| 48/50 [01:06<00:02,  1.42s/it, v_num=1, train_loss_step=908, train_loss_epoch=941]
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# Epoch 50/50:  98%|█████████▊| 49/50 [01:07<00:01,  1.45s/it, v_num=1, train_loss_step=1e+3, train_loss_epoch=941]
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# /opt/miniconda3/envs/fl-course-env/lib/python3.11/site-packages/scvi/module/_vae.py:573: UserWarning: The value argument must be within the support of the distribution
#   reconst_loss = -generative_outputs[MODULE_KEYS.PX_KEY].log_prob(x).sum(-1)
# Epoch 50/50: 100%|██████████| 50/50 [01:09<00:00,  1.46s/it, v_num=1, train_loss_step=1.3e+3, train_loss_epoch=940]
# `Trainer.fit` stopped: `max_epochs=50` reached.
# Epoch 50/50: 100%|██████████| 50/50 [01:09<00:00,  1.39s/it, v_num=1, train_loss_step=1.3e+3, train_loss_epoch=940]

# %%
scvi_ref.save("../model_federated", overwrite=True)
